# %%
# Imports
import os
from predicting_nails.params import *
from predicting_nails.prediction.get_data import *
from PIL import Image
# Out:
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_0.JPG...
# / [1 files][ 49.0 KiB/ 49.0 KiB]
# Operation completed over 1 objects/49.0 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_0.JPG...
# / [1 files][ 10.2 KiB/ 10.2 KiB]
# Operation completed over 1 objects/10.2 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_1.JPG...
# / [1 files][785.9 KiB/785.9 KiB]
# Operation completed over 1 objects/785.9 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_1.JPG...
# / [1 files][124.1 KiB/124.1 KiB]
# Operation completed over 1 objects/124.1 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_2.JPG...
# / [1 files][ 61.6 KiB/ 61.6 KiB]
# Operation completed over 1 objects/61.6 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_2.JPG...
# / [1 files][  9.3 KiB/  9.3 KiB]
# Operation completed over 1 objects/9.3 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_3.JPG...
# / [1 files][ 76.2 KiB/ 76.2 KiB]
# Operation completed over 1 objects/76.2 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_3.JPG...
# / [1 files][471.0 KiB/471.0 KiB]
# Operation completed over 1 objects/471.0 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_4.JPG...
# / [1 files][771.3 KiB/771.3 KiB]
# Operation completed over 1 objects/771.3 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_4.JPG...
# / [1 files][ 12.0 KiB/ 12.0 KiB]
# Operation completed over 1 objects/12.0 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_5.JPG...
# / [1 files][ 63.4 KiB/ 63.4 KiB]
# Operation completed over 1 objects/63.4 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_5.JPG...
# / [1 files][185.0 KiB/185.0 KiB]
# Operation completed over 1 objects/185.0 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_6.JPG...
# / [1 files][842.7 KiB/842.7 KiB]
# Operation completed over 1 objects/842.7 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_6.JPG...
# / [1 files][ 16.4 KiB/ 16.4 KiB]
# Operation completed over 1 objects/16.4 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_7.JPG...
# / [1 files][ 54.7 KiB/ 54.7 KiB]
# Operation completed over 1 objects/54.7 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_7.JPG...
# / [1 files][ 60.3 KiB/ 60.3 KiB]
# Operation completed over 1 objects/60.3 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_8.JPG...
# / [1 files][608.4 KiB/608.4 KiB]
# Operation completed over 1 objects/608.4 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_8.JPG...
# / [1 files][ 16.4 KiB/ 16.4 KiB]
# Operation completed over 1 objects/16.4 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_9.JPG...
# / [1 files][ 56.5 KiB/ 56.5 KiB]
# Operation completed over 1 objects/56.5 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_9.JPG...
# / [1 files][254.6 KiB/254.6 KiB]
# Operation completed over 1 objects/254.6 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_10.JPG...
# / [1 files][758.3 KiB/758.3 KiB]
# Operation completed over 1 objects/758.3 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_10.JPG...
# / [1 files][ 20.5 KiB/ 20.5 KiB]
# Operation completed over 1 objects/20.5 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_11.JPG...
# / [1 files][ 59.3 KiB/ 59.3 KiB]
# Operation completed over 1 objects/59.3 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_11.JPG...
# / [1 files][316.8 KiB/316.8 KiB]
# Operation completed over 1 objects/316.8 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_12.JPG...
# / [1 files][795.6 KiB/795.6 KiB]
# Operation completed over 1 objects/795.6 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_12.JPG...
# / [1 files][ 18.2 KiB/ 18.2 KiB]
# Operation completed over 1 objects/18.2 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_13.JPG...
# / [1 files][ 57.0 KiB/ 57.0 KiB]
# Operation completed over 1 objects/57.0 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_13.JPG...
# / [1 files][432.5 KiB/432.5 KiB]
# Operation completed over 1 objects/432.5 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_14.JPG...
# / [1 files][708.5 KiB/708.5 KiB]
# Operation completed over 1 objects/708.5 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_14.JPG...
# / [1 files][ 19.4 KiB/ 19.4 KiB]
# Operation completed over 1 objects/19.4 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_15.JPG...
# / [1 files][ 44.6 KiB/ 44.6 KiB]
# Operation completed over 1 objects/44.6 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_15.JPG...
# / [1 files][ 18.3 KiB/ 18.3 KiB]
# Operation completed over 1 objects/18.3 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_16.JPG...
# / [1 files][  1.2 MiB/  1.2 MiB]
# Operation completed over 1 objects/1.2 MiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_16.JPG...
# / [1 files][ 18.1 KiB/ 18.1 KiB]
# Operation completed over 1 objects/18.1 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_17.JPG...
# / [1 files][ 45.7 KiB/ 45.7 KiB]
# Operation completed over 1 objects/45.7 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_17.JPG...
# / [1 files][ 22.4 KiB/ 22.4 KiB]
# Operation completed over 1 objects/22.4 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_18.JPG...
# / [1 files][  1.7 MiB/  1.7 MiB]
# Operation completed over 1 objects/1.7 MiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_18.JPG...
# / [1 files][  7.0 KiB/  7.0 KiB]
# Operation completed over 1 objects/7.0 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_19.JPG...
# / [1 files][ 46.7 KiB/ 46.7 KiB]
# Operation completed over 1 objects/46.7 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_19.JPG...
# / [1 files][ 32.1 KiB/ 32.1 KiB]
# Operation completed over 1 objects/32.1 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_20.JPG...
# / [1 files][  1.6 MiB/  1.6 MiB]
# Operation completed over 1 objects/1.6 MiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_20.JPG...
# / [1 files][  4.5 KiB/  4.5 KiB]
# Operation completed over 1 objects/4.5 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_21.JPG...
# / [1 files][ 49.1 KiB/ 49.1 KiB]
# Operation completed over 1 objects/49.1 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_21.JPG...
# / [1 files][ 21.8 KiB/ 21.8 KiB]
# Operation completed over 1 objects/21.8 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_22.JPG...
# / [1 files][  1.2 MiB/  1.2 MiB]
# Operation completed over 1 objects/1.2 MiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_22.JPG...
# / [1 files][  8.0 KiB/  8.0 KiB]
# Operation completed over 1 objects/8.0 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_23.JPG...
# / [1 files][111.8 KiB/111.8 KiB]
# Operation completed over 1 objects/111.8 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_23.JPG...
# / [1 files][ 21.1 KiB/ 21.1 KiB]
# Operation completed over 1 objects/21.1 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_24.JPG...
# / [1 files][  1.6 MiB/  1.6 MiB]
# Operation completed over 1 objects/1.6 MiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_24.JPG...
# / [1 files][  8.9 KiB/  8.9 KiB]
# Operation completed over 1 objects/8.9 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_25.JPG...
# / [1 files][ 76.6 KiB/ 76.6 KiB]
# Operation completed over 1 objects/76.6 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_25.JPG...
# / [1 files][ 27.1 KiB/ 27.1 KiB]
# Operation completed over 1 objects/27.1 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_26.JPG...
# / [1 files][  1.4 MiB/  1.4 MiB]
# Operation completed over 1 objects/1.4 MiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_26.JPG...
# / [1 files][  9.4 KiB/  9.4 KiB]
# Operation completed over 1 objects/9.4 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_27.JPG...
# / [1 files][ 57.3 KiB/ 57.3 KiB]
# Operation completed over 1 objects/57.3 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_27.JPG...
# / [1 files][ 26.4 KiB/ 26.4 KiB]
# Operation completed over 1 objects/26.4 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_28.JPG...
# / [1 files][  1.6 MiB/  1.6 MiB]
# Operation completed over 1 objects/1.6 MiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_28.JPG...
# / [1 files][  1.5 KiB/  1.5 KiB]
# Operation completed over 1 objects/1.5 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_29.JPG...
# / [1 files][ 47.0 KiB/ 47.0 KiB]
# Operation completed over 1 objects/47.0 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_29.JPG...
# / [1 files][ 94.8 KiB/ 94.8 KiB]
# Operation completed over 1 objects/94.8 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_30.JPG...
# / [1 files][  1.6 MiB/  1.6 MiB]
# Operation completed over 1 objects/1.6 MiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_30.JPG...
# / [1 files][  1.5 KiB/  1.5 KiB]
# Operation completed over 1 objects/1.5 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_31.JPG...
# / [1 files][ 97.8 KiB/ 97.8 KiB]
# Operation completed over 1 objects/97.8 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_31.JPG...
# / [1 files][ 93.2 KiB/ 93.2 KiB]
# Operation completed over 1 objects/93.2 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_32.JPG...
# / [1 files][  1.2 MiB/  1.2 MiB]
# Operation completed over 1 objects/1.2 MiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_32.JPG...
# / [1 files][  1.3 KiB/  1.3 KiB]
# Operation completed over 1 objects/1.3 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_33.JPG...
# / [1 files][ 65.8 KiB/ 65.8 KiB]
# Operation completed over 1 objects/65.8 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_33.JPG...
# / [1 files][ 36.7 KiB/ 36.7 KiB]
# Operation completed over 1 objects/36.7 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_34.JPG...
# / [1 files][  1.6 MiB/  1.6 MiB]
# Operation completed over 1 objects/1.6 MiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_34.JPG...
# / [1 files][  1.3 KiB/  1.3 KiB]
# Operation completed over 1 objects/1.3 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_35.JPG...
# / [1 files][700.5 KiB/700.5 KiB]
# Operation completed over 1 objects/700.5 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_35.JPG...
# / [1 files][ 31.4 KiB/ 31.4 KiB]
# Operation completed over 1 objects/31.4 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_36.JPG...
# / [1 files][817.1 KiB/817.1 KiB]
# Operation completed over 1 objects/817.1 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_36.JPG...
# / [1 files][  6.3 KiB/  6.3 KiB]
# Operation completed over 1 objects/6.3 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_37.JPG...
# / [1 files][605.1 KiB/605.1 KiB]
# Operation completed over 1 objects/605.1 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_37.JPG...
# / [1 files][ 31.4 KiB/ 31.4 KiB]
# Operation completed over 1 objects/31.4 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_38.JPG...
# / [1 files][756.2 KiB/756.2 KiB]
# Operation completed over 1 objects/756.2 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_38.JPG...
# / [1 files][  8.4 KiB/  8.4 KiB]
# Operation completed over 1 objects/8.4 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_39.JPG...
# / [1 files][  1.2 MiB/  1.2 MiB]
# Operation completed over 1 objects/1.2 MiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_39.JPG...
# / [1 files][ 35.5 KiB/ 35.5 KiB]
# Operation completed over 1 objects/35.5 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_40.JPG...
# / [1 files][898.6 KiB/898.6 KiB]
# Operation completed over 1 objects/898.6 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_40.JPG...
# / [1 files][  9.2 KiB/  9.2 KiB]
# Operation completed over 1 objects/9.2 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_41.JPG...
# - [1 files][  3.8 MiB/  3.8 MiB]
# Operation completed over 1 objects/3.8 MiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_41.JPG...
# / [1 files][ 26.3 KiB/ 26.3 KiB]
# Operation completed over 1 objects/26.3 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_42.JPG...
# / [1 files][ 61.5 KiB/ 61.5 KiB]
# Operation completed over 1 objects/61.5 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_42.JPG...
# / [1 files][  7.8 KiB/  7.8 KiB]
# Operation completed over 1 objects/7.8 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_43.JPG...
# / [1 files][  1.5 MiB/  1.5 MiB]
# Operation completed over 1 objects/1.5 MiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_43.JPG...
# / [1 files][ 31.6 KiB/ 31.6 KiB]
# Operation completed over 1 objects/31.6 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_44.JPG...
# / [1 files][797.8 KiB/797.8 KiB]
# Operation completed over 1 objects/797.8 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_44.JPG...
# / [1 files][  3.9 KiB/  3.9 KiB]
# Operation completed over 1 objects/3.9 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_45.JPG...
# / [1 files][918.3 KiB/918.3 KiB]
# Operation completed over 1 objects/918.3 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_45.JPG...
# / [1 files][ 22.6 KiB/ 22.6 KiB]
# Operation completed over 1 objects/22.6 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_46.JPG...
# / [1 files][721.4 KiB/721.4 KiB]
# Operation completed over 1 objects/721.4 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_46.JPG...
# / [1 files][  3.7 KiB/  3.7 KiB]
# Operation completed over 1 objects/3.7 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_47.JPG...
# / [1 files][650.4 KiB/650.4 KiB]
# Operation completed over 1 objects/650.4 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_47.JPG...
# / [1 files][ 61.8 KiB/ 61.8 KiB]
# Operation completed over 1 objects/61.8 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_48.JPG...
# / [1 files][  1.6 MiB/  1.6 MiB]
# Operation completed over 1 objects/1.6 MiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_48.JPG...
# / [1 files][ 16.3 KiB/ 16.3 KiB]
# Operation completed over 1 objects/16.3 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/healthy_data/healthy_49.JPG...
# / [1 files][728.8 KiB/728.8 KiB]
# Operation completed over 1 objects/728.8 KiB.
# Copying gs://predicting-nail-diseases/dataset_for_model_1/diseased_data/diseased_49.JPG...
# / [1 files][ 77.6 KiB/ 77.6 KiB]
# Operation completed over 1 objects/77.6 KiB.

# %% [markdown]
# # GET THE DATA FIRST
# to get the data run the get_data.py from your terminal. Make sure you are in "prediction" in your terminal:
#
# ```python
# python get_data.py
# ```
#
# You can check in the raw_data folder if the images appeard.

# %%
# Get resized and labeled data from your local directory
if os.path.exists(LOCAL_DATA_PATH):
    X, y = load_simple_data(LOCAL_DATA_PATH)

# %%
#YOUR CODE HERE
