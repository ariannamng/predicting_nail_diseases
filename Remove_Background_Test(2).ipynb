# %%
# !pip install Pillow
# !pip install rembg
# Out:
# Requirement already satisfied: Pillow in /home/hubertus/.pyenv/versions/3.10.6/envs/predicting_nail_diseases/lib/python3.10/site-packages (10.3.0)
#
# [notice] A new release of pip available: 22.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Collecting rembg
#   Downloading rembg-2.0.57-py3-none-any.whl (33 kB)
# Requirement already satisfied: opencv-python-headless in /home/hubertus/.pyenv/versions/3.10.6/envs/predicting_nail_diseases/lib/python3.10/site-packages (from rembg) (4.10.0.82)
# Requirement already satisfied: scipy in /home/hubertus/.pyenv/versions/3.10.6/envs/predicting_nail_diseases/lib/python3.10/site-packages (from rembg) (1.13.1)
# Collecting jsonschema
#   Using cached jsonschema-4.22.0-py3-none-any.whl (88 kB)
# Requirement already satisfied: numpy in /home/hubertus/.pyenv/versions/3.10.6/envs/predicting_nail_diseases/lib/python3.10/site-packages (from rembg) (1.26.4)
# Collecting pooch
#   Downloading pooch-1.8.1-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: pillow in /home/hubertus/.pyenv/versions/3.10.6/envs/predicting_nail_diseases/lib/python3.10/site-packages (from rembg) (10.3.0)
# Collecting pymatting
#   Downloading PyMatting-1.1.12-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 7.7 MB/s eta 0:00:00
# Collecting onnxruntime
#   Downloading onnxruntime-1.18.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 28.2 MB/s eta 0:00:00a 0:00:01
# Collecting tqdm
#   Downloading tqdm-4.66.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 16.9 MB/s eta 0:00:00
# Collecting scikit-image
#   Downloading scikit_image-0.23.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.7/14.7 MB 31.3 MB/s eta 0:00:0000:0100:01
# Collecting jsonschema-specifications>=2023.03.6
#   Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Collecting referencing>=0.28.4
#   Using cached referencing-0.35.1-py3-none-any.whl (26 kB)
# Collecting rpds-py>=0.7.1
#   Using cached rpds_py-0.18.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
# Collecting attrs>=22.2.0
#   Using cached attrs-23.2.0-py3-none-any.whl (60 kB)
# Requirement already satisfied: flatbuffers in /home/hubertus/.pyenv/versions/3.10.6/envs/predicting_nail_diseases/lib/python3.10/site-packages (from onnxruntime->rembg) (24.3.25)
# Requirement already satisfied: protobuf in /home/hubertus/.pyenv/versions/3.10.6/envs/predicting_nail_diseases/lib/python3.10/site-packages (from onnxruntime->rembg) (4.25.3)
# Requirement already satisfied: packaging in /home/hubertus/.pyenv/versions/3.10.6/envs/predicting_nail_diseases/lib/python3.10/site-packages (from onnxruntime->rembg) (24.0)
# Collecting coloredlogs
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.9 MB/s eta 0:00:00
# Collecting sympy
#   Downloading sympy-1.12.1-py3-none-any.whl (5.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 38.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: platformdirs>=2.5.0 in /home/hubertus/.pyenv/versions/3.10.6/envs/predicting_nail_diseases/lib/python3.10/site-packages (from pooch->rembg) (4.2.2)
# Requirement already satisfied: requests>=2.19.0 in /home/hubertus/.pyenv/versions/3.10.6/envs/predicting_nail_diseases/lib/python3.10/site-packages (from pooch->rembg) (2.32.3)
# Collecting numba!=0.49.0
#   Downloading numba-0.59.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 28.8 MB/s eta 0:00:00a 0:00:01
# Collecting tifffile>=2022.8.12
#   Downloading tifffile-2024.5.22-py3-none-any.whl (225 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.5/225.5 kB 19.8 MB/s eta 0:00:00
# Collecting imageio>=2.33
#   Downloading imageio-2.34.1-py3-none-any.whl (313 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.5/313.5 kB 28.4 MB/s eta 0:00:00
# Collecting lazy-loader>=0.4
#   Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Collecting networkx>=2.8
#   Downloading networkx-3.3-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 36.3 MB/s eta 0:00:00a 0:00:01
# Collecting llvmlite<0.43,>=0.42.0dev0
#   Downloading llvmlite-0.42.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 MB 25.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: certifi>=2017.4.17 in /home/hubertus/.pyenv/versions/3.10.6/envs/predicting_nail_diseases/lib/python3.10/site-packages (from requests>=2.19.0->pooch->rembg) (2024.6.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/hubertus/.pyenv/versions/3.10.6/envs/predicting_nail_diseases/lib/python3.10/site-packages (from requests>=2.19.0->pooch->rembg) (2.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/hubertus/.pyenv/versions/3.10.6/envs/predicting_nail_diseases/lib/python3.10/site-packages (from requests>=2.19.0->pooch->rembg) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/hubertus/.pyenv/versions/3.10.6/envs/predicting_nail_diseases/lib/python3.10/site-packages (from requests>=2.19.0->pooch->rembg) (3.7)
# Collecting humanfriendly>=9.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 12.6 MB/s eta 0:00:00
# Collecting mpmath<1.4.0,>=1.1.0
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 10.0 MB/s eta 0:00:0000:01
# Installing collected packages: mpmath, tqdm, tifffile, sympy, rpds-py, networkx, llvmlite, lazy-loader, imageio, humanfriendly, attrs, scikit-image, referencing, pooch, numba, coloredlogs, pymatting, onnxruntime, jsonschema-specifications, jsonschema, rembg
# Successfully installed attrs-23.2.0 coloredlogs-15.0.1 humanfriendly-10.0 imageio-2.34.1 jsonschema-4.22.0 jsonschema-specifications-2023.12.1 lazy-loader-0.4 llvmlite-0.42.0 mpmath-1.3.0 networkx-3.3 numba-0.59.1 onnxruntime-1.18.0 pooch-1.8.1 pymatting-1.1.12 referencing-0.35.1 rembg-2.0.57 rpds-py-0.18.1 scikit-image-0.23.2 sympy-1.12.1 tifffile-2024.5.22 tqdm-4.66.4
#
# [notice] A new release of pip available: 22.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
import tensorflow as tf
import numpy as np
import cv2
from PIL import Image
import matplotlib.pyplot as plt
import os
from predicting_nails.params import *
from predicting_nails.prediction.get_data import get_simple_data, load_simple_data
# Out:
# 2024-06-06 11:03:50.662735: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-06 11:03:50.665589: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-06 11:03:50.755506: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-06 11:03:51.143978: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-06 11:03:52.654080: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Get resized (224,224,3) and labeled (0,1) data from your local directory for the simple model

nb_healthy = 50     #defines the number of healthy images to be downloaded and loaded
nb_disease = 50     #defines the number of diseased images to be downloaded and loaded

if os.path.exists(os.path.join(LOCAL_DATA_PATH, "dataset_for_model_1")) == False:
    get_simple_data(nb_healthy = nb_healthy, nb_disease = nb_disease)
    X, y = load_simple_data(LOCAL_DATA_PATH, nb_healthy = nb_healthy, nb_disease = nb_disease)
else:
    X, y = load_simple_data(LOCAL_DATA_PATH, nb_healthy = nb_healthy, nb_disease = nb_disease)

# %%
image_array = X[20]
image_array
# Out:
# array([[[123, 121, 126],
#         [124, 123, 128],
#         [124, 122, 127],
#         ...,
#         [127, 125, 126],
#         [129, 126, 128],
#         [130, 126, 127]],
#
#        [[123, 121, 124],
#         [123, 121, 126],
#         [124, 122, 126],
#         ...,
#         [126, 124, 125],
#         [127, 125, 127],
#         [130, 126, 127]],
#
#        [[123, 121, 124],
#         [123, 121, 124],
#         [124, 122, 125],
#         ...,
#         [125, 124, 126],
#         [126, 125, 127],
#         [126, 125, 126]],
#
#        ...,
#
#        [[100, 100, 102],
#         [100, 101, 103],
#         [100, 101, 103],
#         ...,
#         [157,  95,  84],
#         [145,  81,  71],
#         [143,  75,  66]],
#
#        [[102, 102, 104],
#         [100, 101, 103],
#         [101, 102, 104],
#         ...,
#         [122,  61,  50],
#         [135,  72,  61],
#         [141,  75,  64]],
#
#        [[103, 103, 105],
#         [102, 102, 104],
#         [101, 101, 103],
#         ...,
#         [138,  76,  65],
#         [139,  76,  65],
#         [140,  74,  62]]], dtype=uint8)

# %%
# Importing Required Modules
from rembg import remove
from PIL import Image

# Store path of the image in the variable input_path
input_path =  'raw_data/dataset_for_model_1/healthy_31.JPG'

# Store path of the output image in the variable output_path
output_path = 'raw_data/dataset_for_model_1/healthy_31_new.JPG'

# Processing the image
input = Image.open(input_path)

# Removing the background from the given Image
output = remove(input)

output = output.convert("RGB")

#Saving the image in the given path
output.save(output_path)

# %%
# Importing Required Modules
from rembg import remove
from PIL import Image

# Store path of the image in the variable input_path
input_path =  'raw_data/dataset_for_model_1/healthy_13.JPG'

# Store path of the output image in the variable output_path
output_path = 'raw_data/dataset_for_model_1/healthy_13_new.JPG'

# Processing the image
input = Image.open(input_path)

# Removing the background from the given Image
output = remove(input)

output = output.convert("RGB")

#Saving the image in the given path
output.save(output_path)

# %%
# Importing Required Modules
from rembg import remove
from PIL import Image

# Store path of the image in the variable input_path
input_path =  'raw_data/dataset_for_model_1/healthy_13.JPG'

# Store path of the output image in the variable output_path
output_path = 'raw_data/dataset_for_model_1/healthy_13_new.JPG'

# Processing the image
input = Image.open(input_path)

# Removing the background from the given Image
output = remove(input)

output = output.convert("RGB")

#Saving the image in the given path
output.save(output_path)
